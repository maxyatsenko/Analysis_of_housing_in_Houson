# %% [markdown]
# # This Jupyter Notebook imports Excel File with Housing

# %% [markdown]
# ## and tells the best options based on data...

# %% [markdown]
# I personally was looking for 1 bedroom / studio in range up to USD 1,500/month.
#
# In addition, I wanted the place with good reviews.
#
# Also, I needed 3 months only, so it wasn't that easy...
#
# I expect to choose 5 places out of 150 :)

# %% [markdown]
# Let's start by importing our excel file:

# %%
import pandas as pd
from IPython.display import display
houses = pd.read_excel('Housing.xlsx')
display(houses.head())
# Out:
#    Count                               Name S/1b/2b $/month Minimum Term  \
# 0      1                   Heights Park Row     NaN     NaN          NaN
# 1      2       14220 Apartments at Park Row     NaN     NaN          NaN
# 2      3  The Legend at Park Ten Apartments     NaN     NaN          NaN
# 3      4                 Park Place Houston     NaN     NaN          NaN
# 4      5                Marquis on Park Row     NaN     NaN          NaN
#
#       By Bike  By Bus  #buses Reviews Google  Yelp Reviews  \
# 0  22 minutes  1:30hr     2.0            Bad           NaN
# 1      27 min  1:20hr     2.0       Terrible           NaN
# 2      31 min  1:40hr     2.0            Bad           NaN
# 3         NaN     NaN     NaN       Terrible           NaN
# 4         NaN     NaN     NaN       Terrible           NaN
#
#                                              webpage emailed? called? Love?  \
# 0   https://www.heightsparkrow.com/Marketing/Contact      Yes      No    No
# 1  https://www.14220houstonapartments.com/houston...       No      No    No
# 2  https://www.legendatparkten.com/?utm_source=Go...       No      No    No
# 3                                                NaN       No      No    No
# 4  https://www.cwsapartments.com/marquis-on-park-...       No      No    No
#
#                                             Comments
# 0                                                NaN
# 1                        Overcharged when moving out
# 2  Don’t allow other people to sleep in apparantl...
# 3                                        Crime, bugs
# 4                     Crime, roaches, no maintanence

# %% [markdown]
# Now let's get rid of NaNs first, and the count column (which is quite useless here):

# %%
del houses['Count']
houses['$/month'] = houses['$/month'].fillna(0)
houses = houses.fillna('?')
display(houses.head())
# Out:
#                                 Name S/1b/2b $/month Minimum Term     By Bike  \
# 0                   Heights Park Row       ?       0            ?  22 minutes
# 1       14220 Apartments at Park Row       ?       0            ?      27 min
# 2  The Legend at Park Ten Apartments       ?       0            ?      31 min
# 3                 Park Place Houston       ?       0            ?           ?
# 4                Marquis on Park Row       ?       0            ?           ?
#
#    By Bus #buses Reviews Google Yelp Reviews  \
# 0  1:30hr      2            Bad            ?
# 1  1:20hr      2       Terrible            ?
# 2  1:40hr      2            Bad            ?
# 3       ?      ?       Terrible            ?
# 4       ?      ?       Terrible            ?
#
#                                              webpage emailed? called? Love?  \
# 0   https://www.heightsparkrow.com/Marketing/Contact      Yes      No    No
# 1  https://www.14220houstonapartments.com/houston...       No      No    No
# 2  https://www.legendatparkten.com/?utm_source=Go...       No      No    No
# 3                                                  ?       No      No    No
# 4  https://www.cwsapartments.com/marquis-on-park-...       No      No    No
#
#                                             Comments
# 0                                                  ?
# 1                        Overcharged when moving out
# 2  Don’t allow other people to sleep in apparantl...
# 3                                        Crime, bugs
# 4                     Crime, roaches, no maintanence

# %% [markdown]
# I think that's it so far for preprocessing :)
#
# Let's now select the best candidates...

# %% [markdown]
# ## Shortlist1: The best candidates as of right now

# %% [markdown]
# Idea1: I need 3 months or below as a Minimum Term length.
#
# Idea2: I need price below $1,500/month.
#
# Idea3: Reviews should be decent.

# %% [markdown]
# First 2 ideas seem straightforward. How to go about third? I used word classification there. Let's see all the options:

# %%
houses['Reviews Google'].unique()
# Out:
# array(['Bad', 'Terrible', 'Ok', '?', 'Awesome', 'Good', 'The worst lol',
#        'The worst', 'No Raiting', 'Amazing'], dtype=object)

# %% [markdown]
# My idea of decent would be:
#
# Ok
# Good
# Awesome
# Amazing
#
# I want to also give chance to:
#
# ?
# No Raiting (raiting eh?)
#
# In other words I say 'No' to:
#
# Bad
# Terrible
# The worst
# The worst lol

# %%
good_rating = ['Ok', 'Good', '?', 'Awesome', 'No Raiting', 'Amazing']
shortlist1 = houses.loc[houses['Reviews Google'].isin(good_rating)]
del shortlist1['webpage']
del shortlist1['emailed?']
del shortlist1['called?']
display(shortlist1.head())
# Out:
#                       Name S/1b/2b $/month Minimum Term By Bike  By Bus  \
# 7   Broadstone Energy Park       ?       0    12 months  34 min  1:35hr
# 10    Sunrise Briar Forest       ?    1140     3 months       ?       ?
# 11   Vista Energy Corridor      1b    1500     3 months       ?       ?
# 13      Aliso Briar Forest       ?    1907     3 months       ?       ?
# 14   The Grand on Memorial       ?    1105     3 months       ?       ?
#
#    #buses Reviews Google Yelp Reviews Love?  \
# 7       2             Ok            ?    No
# 10      ?             Ok            ?    No
# 11      ?              ?            ?     ?
# 13      ?        Awesome            ?     ?
# 14      ?              ?            ?     ?
#
#                                              Comments
# 7                                             Roaches
# 10  Rude, roaches, spiders, lots of 5-star revies ...
# 11                                                  ?
# 13                                                  ?
# 14                                                  ?

# %% [markdown]
# Now let's think about how we can select 3 months and below.
#
# Let's actually see if there are values below 3 months:

# %%
shortlist1['Minimum Term'].unique()
# Out:
# array(['12 months', '3 months', '?', '1 month', '6 months', '4 months',
#        '5 months', '3 Months', '10 months', '7 months'], dtype=object)

# %% [markdown]
# I think it'll be actually very nice to apply simple regular expression processing here :)

# %%
import re

def min_term_processing(value):
    m = re.match("^(\d{1})\s+", value)
    if m is None or len(m.groups()) > 2:
        return 12
    else:
        return int(m.groups()[0])
    
shortlist1['Minimum Term'] = shortlist1['Minimum Term'].map(min_term_processing)
shortlist1 = shortlist1.loc[shortlist1['Minimum Term'] < 4]
display(shortlist1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                      Name S/1b/2b $/month  Minimum Term By Bike By Bus #buses  \
# 10   Sunrise Briar Forest       ?    1140             3       ?      ?      ?
# 11  Vista Energy Corridor      1b    1500             3       ?      ?      ?
# 13     Aliso Briar Forest       ?    1907             3       ?      ?      ?
# 14  The Grand on Memorial       ?    1105             3       ?      ?      ?
# 16              7-Seventy       ?       ?             1       ?      ?      ?
#
#    Reviews Google Yelp Reviews Love?  \
# 10             Ok            ?    No
# 11              ?            ?     ?
# 13        Awesome            ?     ?
# 14              ?            ?     ?
# 16              ?            ?     ?
#
#                                              Comments
# 10  Rude, roaches, spiders, lots of 5-star revies ...
# 11                                                  ?
# 13                                                  ?
# 14                                                  ?
# 16    3 Months or even 1 month based on their webpage

# %% [markdown]
# Now let's get rid of too expensive ones:

# %%
shortlist1 = shortlist1[pd.to_numeric(shortlist1['$/month'], errors='coerce').notnull()]
shortlist1 = shortlist1.loc[shortlist1['$/month'] < 1501]
# Out:
#                                    Name S/1b/2b $/month  Minimum Term By Bike  \
# 10                 Sunrise Briar Forest       ?    1140             3       ?
# 11                Vista Energy Corridor      1b    1500             3       ?
# 14                The Grand on Memorial       ?    1105             3       ?
# 36   The Retreat at Eldridge Apartments      1b    1270             3       ?
# 48              Mandalay at Shadow Lake      1b    1153             3  36 min
# 61                   Plaza at Westchase       ?    1440             3       ?
# 64                 Marquis at Westchase       ?    1384             3       ?
# 78                 District at Memorial      1b    1350             3       ?
# 80                           Creekstone       ?    1365             3       ?
# 93                  Walden of Westchase      2b    1102             3       ?
# 99             The Commons at Westchase       ?    1500             3       ?
# 101         The Lodge at Spring Shadows      1b    1381             3       ?
# 118                              Zocalo       ?     986             3       ?
#
#     By Bus #buses Reviews Google Yelp Reviews Love?  \
# 10       ?      ?             Ok            ?    No
# 11       ?      ?              ?            ?     ?
# 14       ?      ?              ?            ?     ?
# 36       ?      ?             Ok            ?     ?
# 48       ?      ?           Good            ?   Yes
# 61       ?      ?           Good            ?     ?
# 64       ?      ?        Awesome            ?     ?
# 78       ?      ?              ?            ?   Yes
# 80       ?      ?        Awesome            ?     ?
# 93       ?      ?             Ok            ?    No
# 99       ?      ?             Ok            ?     ?
# 101      ?      ?           Good            ?   Yes
# 118      ?      ?        Awesome            ?     ?
#
#                                               Comments
# 10   Rude, roaches, spiders, lots of 5-star revies ...
# 11                                                   ?
# 14                                                   ?
# 36                                                   ?
# 48                                                   ?
# 61   So its 1,400 for 2 months, but for 3 months it...
# 64                                                   ?
# 78                                                   ?
# 80                                                   ?
# 93                          Amenities are horrible tbh
# 99                                                   ?
# 101                                                  ?
# 118  Idk man the reviews arefrom the guys with 0 re...

# %% [markdown]
# ## AND here we are! Shortlist # 1, Ladies and Gentelmen :)

# %%
display(shortlist1.sort_values(['Love?', '$/month'], ascending=[False, True]))
# Out:
#                                    Name S/1b/2b $/month  Minimum Term By Bike  \
# 48              Mandalay at Shadow Lake      1b    1153             3  36 min
# 78                 District at Memorial      1b    1350             3       ?
# 101         The Lodge at Spring Shadows      1b    1381             3       ?
# 93                  Walden of Westchase      2b    1102             3       ?
# 10                 Sunrise Briar Forest       ?    1140             3       ?
# 118                              Zocalo       ?     986             3       ?
# 14                The Grand on Memorial       ?    1105             3       ?
# 36   The Retreat at Eldridge Apartments      1b    1270             3       ?
# 80                           Creekstone       ?    1365             3       ?
# 64                 Marquis at Westchase       ?    1384             3       ?
# 61                   Plaza at Westchase       ?    1440             3       ?
# 11                Vista Energy Corridor      1b    1500             3       ?
# 99             The Commons at Westchase       ?    1500             3       ?
#
#     By Bus #buses Reviews Google Yelp Reviews Love?  \
# 48       ?      ?           Good            ?   Yes
# 78       ?      ?              ?            ?   Yes
# 101      ?      ?           Good            ?   Yes
# 93       ?      ?             Ok            ?    No
# 10       ?      ?             Ok            ?    No
# 118      ?      ?        Awesome            ?     ?
# 14       ?      ?              ?            ?     ?
# 36       ?      ?             Ok            ?     ?
# 80       ?      ?        Awesome            ?     ?
# 64       ?      ?        Awesome            ?     ?
# 61       ?      ?           Good            ?     ?
# 11       ?      ?              ?            ?     ?
# 99       ?      ?             Ok            ?     ?
#
#                                               Comments
# 48                                                   ?
# 78                                                   ?
# 101                                                  ?
# 93                          Amenities are horrible tbh
# 10   Rude, roaches, spiders, lots of 5-star revies ...
# 118  Idk man the reviews arefrom the guys with 0 re...
# 14                                                   ?
# 36                                                   ?
# 80                                                   ?
# 64                                                   ?
# 61   So its 1,400 for 2 months, but for 3 months it...
# 11                                                   ?
# 99                                                   ?

# %% [markdown]
# ## Shortlist2: potential candidates

# %% [markdown]
# This list includes those places that have a really nice rating, but no information about leasing length.
#
# So, potentially, they can be your new home, you just need to call them :)

# %% [markdown]
# Idea1: Minimum Term is '?'
#
# Idea2: Rating is 'Good' or 'Awesome' or 'Amazing' (and mb '?' too :) )

# %%
shortlist2 = houses.copy()
shortlist2 = shortlist2.loc[shortlist2['Minimum Term'] == '?']
perfect_rating = ['Good', '?', 'Awesome', 'Amazing']
shortlist2 = shortlist2.loc[shortlist2['Reviews Google'].isin(perfect_rating)]
shortlist2 = shortlist2.loc[shortlist2['Name'] != '?']
del shortlist2['webpage']
display(shortlist2)
# Out:
#                                Name S/1b/2b $/month Minimum Term By Bike  \
# 15              Broadstone Memorial       ?       0            ?       ?
# 54              Ashford Briar Point       ?       0            ?       ?
# 68                 Westchase Forest       ?       0            ?       ?
# 70            Upland Park Townhomes       ?       0            ?       ?
# 71                Memorial Fountain       ?       0            ?       ?
# 116                    Laguna Vista       ?       0            ?       ?
# 127                  Alexan Enclave       ?       0            ?       ?
# 131                       Arrabella       ?       0            ?       ?
# 133         Jackson Hill Apartments       ?       0            ?       ?
# 134        Fairmont Museum District       ?       0            ?       ?
# 136                   1900 Yorktown       ?       0            ?       ?
# 139  The Fountains at Memorial City       ?       0            ?       ?
#
#     By Bus #buses Reviews Google Yelp Reviews emailed? called? Love?  \
# 15       ?      ?              ?            ?      Yes       ?     ?
# 54       ?      ?        Awesome            ?      Yes       ?   Yes
# 68       ?      ?           Good            ?      Yes       ?     ?
# 70       ?      ?              ?            ?        ?       ?     ?
# 71       ?      ?           Good            ?      Yes      No   Yes
# 116      ?      ?           Good            ?      Yes       ?     ?
# 127      ?      ?           Good            ?      Yes       ?   Yes
# 131      ?      ?           Good            ?        ?       ?   Yes
# 133      ?      ?        Awesome            ?      Yes       ?   Yes
# 134      ?      ?        Awesome            ?      Yes       ?   Yes
# 136      ?      ?        Awesome            ?      Yes       ?   Yes
# 139      ?      ?              ?            ?        ?       ?     ?
#
#                   Comments
# 15                       ?
# 54                       ?
# 68                       ?
# 70                       ?
# 71   Klie's recommendation
# 116                      ?
# 127                      ?
# 131                      ?
# 133                      ?
# 134                      ?
# 136                      ?
# 139                      ?
